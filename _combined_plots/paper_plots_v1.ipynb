# %% [markdown]
# <h1> Draft Plots for Chlorine & Methane Paper </h1>

# %%
# Display the date when this notebook was run.
from datetime import datetime
from IPython.display import display, Markdown
todays_date = str(datetime.now().date())
display(Markdown(f'<h3> Plots Generated on {todays_date} </h3>'))
# Out:
# <h3> Plots Generated on 2025-01-14 </h3>

# %%
# Load necessary libraries
import matplotlib.pyplot as plt
import importlib
from matplotlib.gridspec import GridSpec
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../_shared_packages')
import cl2_utilities as cl2_utils

# %%
# Shared settings for plots and fonts
subplot_letter_size = 20
subplot_letter_weight = 'bold'
figure_width = 10
plt.rcParams['figure.constrained_layout.use'] = True
plt.rcParams.update({'font.size': 14})

# Store line colors, styles, and markdown labels so we can change them easily and don't need to repeat them.
default_properties = {'CH4':{'color':'C0','marker':'o','linestyle':'--','text':'-$\Delta$CH$_4$'},
                      'Cl2':{'color':'g','marker':'o','linestyle':'--','text':'-$\Delta$Cl$_2$'},
                      'CO2':{'color':'xkcd:violet','marker':'o','linestyle':'--','text':'$\Delta$CO$_2$'},
                      'CO':{'color':'xkcd:teal','marker':'o','linestyle':'--','text':'$\Delta$CO',},
                      'CH2O':{'color':'xkcd:navy','marker':'o','linestyle':'--','text':'$\Delta$CH$_2$O'},
                      'C1 Sum':{'color':'xkcd:pink','marker':'o','linestyle':':','text':'$\Delta$CO+$\Delta$CO$_2$+$\Delta$CH$_2$O'},
                      'Cl* Efficiency':{'color':'xkcd:olive','marker':'o','linestyle':':','text':'[Placeholder]'},
                      }

# Grab the constants stored in the Cl2 utilities
importlib.reload(cl2_utils)
cl2_experiment_constants = cl2_utils.cl2_experiment_constants()

# %%
# Load the data frames for the plotting scripts to reference

# %% [markdown]
# Notes about plotting best practices:
# * Try to save figures with descriptive file names like "co_fed_gas_results.png", not "figure_1.png". That way, we don't have to tediously rename a ton of things in code if we insert a figure in the middle; we just have to fix the headers in this file and the references in the paper.
# * Let's try to rely more on Github version history to get old plots if we want them, rather than having a big python folder of deprecated plotting functions that are broken or useless in various ways.
# * [Add anything else to keep in mind here.]

# %% [markdown]
# <h2>Figure 1: Results from the 'base case'</h2>

# %%
(fig,((ax_a,ax_b)))=plt.subplots(1,2,figsize=(figure_width,4))

# a
ax_a.text(-0.18,1.05, "(a)", transform=ax_a.transAxes, size=subplot_letter_size, weight='bold')

# b
ax_b.text(-0.18,1.05, "(b)", transform=ax_b.transAxes, size=subplot_letter_size, weight='bold')

plt.savefig('paper_plots_v1_exported/base_case_results.png', bbox_inches='tight',dpi=300)
plt.show()

# %% [markdown]
# <h2>Figure 2: Results from varying methane and chlorine concentrations</h2>

# %%
(fig,((ax_a,ax_b)))=plt.subplots(1,2,figsize=(figure_width,4))

# a
ax_a.text(-0.18,1.05, "(a)", transform=ax_a.transAxes, size=subplot_letter_size, weight='bold')

# b
ax_b.text(-0.18,1.05, "(b)", transform=ax_b.transAxes, size=subplot_letter_size, weight='bold')

plt.savefig('paper_plots_v1_exported/vary_ch4_cl2_results.png', bbox_inches='tight',dpi=300)
plt.show()

# %% [markdown]
# <h2>Table 1: Results on which CH4-to-Cl2 ratio is most efficient</h2>

# %%
# Code here

# %% [markdown]
# <h2>Figure 3: Results from varying co-fed gas concentrations</h2>

# %%
(fig,(((ax_a,ax_b),(ax_c,ax_d))))=plt.subplots(2,2,figsize=(figure_width,8))

# a
ax_a.text(-0.18,1.05, "(a)", transform=ax_a.transAxes, size=subplot_letter_size, weight='bold')

# b
ax_b.text(-0.18,1.05, "(b)", transform=ax_b.transAxes, size=subplot_letter_size, weight='bold')

# c
ax_c.text(-0.18,1.05, "(c)", transform=ax_c.transAxes, size=subplot_letter_size, weight='bold')

# d
ax_d.text(-0.18,1.05, "(d)", transform=ax_d.transAxes, size=subplot_letter_size, weight='bold')

plt.savefig('paper_plots_v1_exported/vary_co_fed_gases_results.png', bbox_inches='tight',dpi=300)
plt.show()

# %% [markdown]
# <h2>Figure 4: Results from 'real-world' tests; cost projection contour plot</h2>

# %%
(fig,((ax_a,ax_b)))=plt.subplots(1,2,figsize=(figure_width,4))

# a
ax_a.text(-0.18,1.05, "(a)", transform=ax_a.transAxes, size=subplot_letter_size, weight='bold')

# b
ax_b.text(-0.18,1.05, "(b)", transform=ax_b.transAxes, size=subplot_letter_size, weight='bold')

plt.savefig('paper_plots_v1_exported/vary_ch4_cl2_results.png', bbox_inches='tight',dpi=300)
plt.show()

# %% [markdown]
# <h1> Supporting Information </h1>

# %% [markdown]
# <h2> Figure S1: Time-series plot of conversion of 2-ppm methane </h2>

# %%
(fig,ax)=plt.subplots(1,1,figsize=(figure_width,4))

plt.savefig('paper_plots_v1_exported/time_series_2_ppm.png', bbox_inches='tight',dpi=300)
plt.show()
